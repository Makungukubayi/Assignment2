# %%
import pandas as pd
data=pd.read_csv("Corruption1.csv",sep=",")
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import skew
import scipy
from scipy import stats
import pandas as pd
import statistics
import seaborn as sns
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew

# %% [markdown]
# ### Comment
#
#                                                    #Introduction
#
# I am using my Corruption 2019 which i have name as Corruption one/1 to do my statistics calculation this assist me to define my data and clean them to creating meaningful information.
#
# # Excel Stats
#
# on my last project i used the same data sets on excel when i had to do my calculation manulally using formulars that i had to resarch.
#
# # Python Stats
#
# I am using my corruption raw data set to define the corruption stats 2019 in India where im calculating the mean mode std etc..
# This will assist me to create graphs that will compare diffrent states in india.

# %%
data.columns = data.columns.str.strip()

# %%
print ((data).isnull())
# Out:
#     Category  State_UT  Cases_Pending_Investigation_from_Previous_Year  \
# 0      False     False                                           False
# 1      False     False                                           False
# 2      False     False                                           False
# 3      False     False                                           False
# 4      False     False                                           False
# 5      False     False                                           False
# 6      False     False                                           False
# 7      False     False                                           False
# 8      False     False                                           False
# 9      False     False                                           False
# 10     False     False                                           False
# 11     False     False                                           False
# ...

# %%
# calculating Mean
data.mean()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\3996734311.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Category                                            1.194444
# State_UT                                           17.361111
# Cases_Pending_Investigation_from_Previous_Year    274.583333
# Cases_Reported_during_the_year                    117.861111
# Cases_ReOpened_for_Investigation                    0.638889
# Cases_Transferred_to_other_1_or_Agency              0.583333
# Cases_With_drawn_by_the_Govt                        0.027778
# Cases_in_Which_Final_Reports_Submitted             16.416667
# Cases_Charge_sheeted                               74.972222
# Cases_Pending_Investigation_at_End_of_the_Year    301.083333
# ...

# %%
# Calculating Mode
data.mode()
# Out:
#    Category  State_UT  Cases_Pending_Investigation_from_Previous_Year  \
# 0       1.0       8.0                                               1
# 1       NaN      22.0                                               8
# 2       NaN       NaN                                              13
#
#    Cases_Reported_during_the_year  Cases_ReOpened_for_Investigation  \
# 0                             0.0                               0.0
# 1                             1.0                               NaN
# 2                             NaN                               NaN
#
#    Cases_Transferred_to_other_1_or_Agency  Cases_With_drawn_by_the_Govt  \
# 0                                     0.0                           0.0
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
#
#    Cases_in_Which_Final_Reports_Submitted  Cases_Charge_sheeted  \
# ...

# %%
# calculating Median
data.median()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\3546763261.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Category                                            1.0
# State_UT                                           17.5
# Cases_Pending_Investigation_from_Previous_Year     82.5
# Cases_Reported_during_the_year                     18.5
# Cases_ReOpened_for_Investigation                    0.0
# Cases_Transferred_to_other_1_or_Agency              0.0
# Cases_With_drawn_by_the_Govt                        0.0
# Cases_in_Which_Final_Reports_Submitted              4.5
# Cases_Charge_sheeted                               16.5
# Cases_Pending_Investigation_at_End_of_the_Year    113.5
# ...

# %%
# calculating kurtosis
data.kurtosis()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\2156228077.py:2: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# Category                                           0.630647
# State_UT                                          -1.187591
# Cases_Pending_Investigation_from_Previous_Year     3.827203
# Cases_Reported_during_the_year                     7.608784
# Cases_ReOpened_for_Investigation                   8.092157
# Cases_Transferred_to_other_1_or_Agency             8.037360
# Cases_With_drawn_by_the_Govt                      36.000000
# Cases_in_Which_Final_Reports_Submitted             8.065483
# Cases_Charge_sheeted                              19.351688
# Cases_Pending_Investigation_at_End_of_the_Year     3.571234
# ...

# %%
# calculating Count
data.count()
# Out:
# Category                                          36
# State_UT                                          36
# Cases_Pending_Investigation_from_Previous_Year    36
# Cases_Reported_during_the_year                    36
# Cases_ReOpened_for_Investigation                  36
# Cases_Transferred_to_other_1_or_Agency            36
# Cases_With_drawn_by_the_Govt                      36
# Cases_in_Which_Final_Reports_Submitted            36
# Cases_Charge_sheeted                              36
# Cases_Pending_Investigation_at_End_of_the_Year    36
# Total_cases                                       36
# Unnamed: 11                                        0
# Unnamed: 12                                        0
# Unnamed: 13                                        0
# Unnamed: 14                                        1
# dtype: int64

# %%
# calculating Standard devitation
data.std()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\3092963419.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# Category                                            0.401386
# State_UT                                            9.830427
# Cases_Pending_Investigation_from_Previous_Year    389.851721
# Cases_Reported_during_the_year                    186.336125
# Cases_ReOpened_for_Investigation                    1.658791
# Cases_Transferred_to_other_1_or_Agency              1.401530
# Cases_With_drawn_by_the_Govt                        0.166667
# Cases_in_Which_Final_Reports_Submitted             33.116569
# Cases_Charge_sheeted                              144.509710
# Cases_Pending_Investigation_at_End_of_the_Year    420.599054
# ...

# %%
# calculating Percentile 75,25.50
percent25 = data.quantile(0.25)
print(f"this is the percentile 25{percent25}")
# Out:
# this is the percentile 25Category                                           1.00
# State_UT                                           8.75
# Cases_Pending_Investigation_from_Previous_Year    16.00
# Cases_Reported_during_the_year                     5.00
# Cases_ReOpened_for_Investigation                   0.00
# Cases_Transferred_to_other_1_or_Agency             0.00
# Cases_With_drawn_by_the_Govt                       0.00
# Cases_in_Which_Final_Reports_Submitted             1.00
# Cases_Charge_sheeted                               2.00
# Cases_Pending_Investigation_at_End_of_the_Year    15.75
# Total_cases                                       20.75
# Unnamed: 11                                         NaN
# Unnamed: 12                                         NaN
# Unnamed: 13                                         NaN
# Name: 0.25, dtype: float64
# ...

# %%
# calculating Percentile 75,25.50
percent75 = data.quantile(0.75)
print(f"this is the percentile 75{percent75}")
# Out:
# this is the percentile 75Category                                            1.00
# State_UT                                           25.25
# Cases_Pending_Investigation_from_Previous_Year    345.00
# Cases_Reported_during_the_year                    142.75
# Cases_ReOpened_for_Investigation                    0.00
# Cases_Transferred_to_other_1_or_Agency              0.00
# Cases_With_drawn_by_the_Govt                        0.00
# Cases_in_Which_Final_Reports_Submitted             11.25
# Cases_Charge_sheeted                               79.25
# Cases_Pending_Investigation_at_End_of_the_Year    398.50
# Total_cases                                       489.50
# Unnamed: 11                                          NaN
# Unnamed: 12                                          NaN
# Unnamed: 13                                          NaN
# Name: 0.75, dtype: float64
# ...

# %%
# calculating Percentile 75,25.50
percent50 = data.quantile(0.50)
print(f"this is the percentile 50{percent50}")
# Out:
# this is the percentile 50Category                                            1.0
# State_UT                                           17.5
# Cases_Pending_Investigation_from_Previous_Year     82.5
# Cases_Reported_during_the_year                     18.5
# Cases_ReOpened_for_Investigation                    0.0
# Cases_Transferred_to_other_1_or_Agency              0.0
# Cases_With_drawn_by_the_Govt                        0.0
# Cases_in_Which_Final_Reports_Submitted              4.5
# Cases_Charge_sheeted                               16.5
# Cases_Pending_Investigation_at_End_of_the_Year    113.5
# Total_cases                                       151.5
# Unnamed: 11                                         NaN
# Unnamed: 12                                         NaN
# Unnamed: 13                                         NaN
# Name: 0.5, dtype: float64
# ...

# %%
data.var()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\445316826.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# Category                                               0.161111
# State_UT                                              96.637302
# Cases_Pending_Investigation_from_Previous_Year    151984.364286
# Cases_Reported_during_the_year                     34721.151587
# Cases_ReOpened_for_Investigation                       2.751587
# Cases_Transferred_to_other_1_or_Agency                 1.964286
# Cases_With_drawn_by_the_Govt                           0.027778
# Cases_in_Which_Final_Reports_Submitted              1096.707143
# Cases_Charge_sheeted                               20883.056349
# ...

# %%
data.skew()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# Category                                          1.612059
# State_UT                                          0.020481
# Cases_Pending_Investigation_from_Previous_Year    1.992516
# Cases_Reported_during_the_year                    2.491763
# Cases_ReOpened_for_Investigation                  2.883341
# Cases_Transferred_to_other_1_or_Agency            2.852040
# Cases_With_drawn_by_the_Govt                      6.000000
# Cases_in_Which_Final_Reports_Submitted            2.952207
# Cases_Charge_sheeted                              3.997592
# Cases_Pending_Investigation_at_End_of_the_Year    1.928841
# ...

# %%
# Other Calculation formulated by me
data.max()-data.min()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\781371151.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()-data.min()
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\781371151.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()-data.min()
# Category                                             1.0
# State_UT                                            33.0
# Cases_Pending_Investigation_from_Previous_Year    1609.0
# Cases_Reported_during_the_year                     891.0
# ...

# %%
# Calculating Minimum
data.min()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\969933091.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.min()
# Category                                          1.0
# State_UT                                          1.0
# Cases_Pending_Investigation_from_Previous_Year    1.0
# Cases_Reported_during_the_year                    0.0
# Cases_ReOpened_for_Investigation                  0.0
# Cases_Transferred_to_other_1_or_Agency            0.0
# Cases_With_drawn_by_the_Govt                      0.0
# Cases_in_Which_Final_Reports_Submitted            0.0
# Cases_Charge_sheeted                              0.0
# Cases_Pending_Investigation_at_End_of_the_Year    1.0
# Total_cases                                       1.0
# ...

# %%
# Calculating Maximum
data.max()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\2904433368.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()
# Category                                             2.0
# State_UT                                            34.0
# Cases_Pending_Investigation_from_Previous_Year    1610.0
# Cases_Reported_during_the_year                     891.0
# Cases_ReOpened_for_Investigation                     7.0
# Cases_Transferred_to_other_1_or_Agency               6.0
# Cases_With_drawn_by_the_Govt                         1.0
# Cases_in_Which_Final_Reports_Submitted             141.0
# Cases_Charge_sheeted                               808.0
# Cases_Pending_Investigation_at_End_of_the_Year    1694.0
# ...

# %%
# Calculating Range

Category= data['Category'].max() - data['Category'].min()
State_UT= data['State_UT'].max() - data['State_UT'].min()
Cases_Pending_Investigation_from_Previous_Year= data['Cases_Pending_Investigation_from_Previous_Year'].max() - data['Cases_Pending_Investigation_from_Previous_Year'].min()
Cases_Reported_during_the_year= data['Cases_Reported_during_the_year'].max() - data['Cases_Reported_during_the_year'].min()
Cases_ReOpened_for_Investigation= data['Cases_ReOpened_for_Investigation'].max() - data['Cases_ReOpened_for_Investigation'].min()
Cases_Transferred_to_other_1_or_Agency= data['Cases_Transferred_to_other_1_or_Agency'].max() - data['Cases_Transferred_to_other_1_or_Agency'].min()
Cases_in_Which_Final_Reports_Submitted= data['Cases_in_Which_Final_Reports_Submitted'].max() - data['Cases_in_Which_Final_Reports_Submitted'].min()
Cases_With_drawn_by_the_Govt= data['Cases_With_drawn_by_the_Govt'].max() - data['Cases_With_drawn_by_the_Govt'].min()
Cases_Charge_sheeted= data['Cases_Charge_sheeted'].max() - data['Cases_Charge_sheeted'].min()
Cases_Pending_Investigation_at_End_of_the_Year= data['Cases_Pending_Investigation_at_End_of_the_Year'].max() - data['Cases_Pending_Investigation_at_End_of_the_Year'].min()
Total_cases= data['Total_cases'].max() - data['Total_cases'].min()


print(f"The Range of Category is : {Category}.")
print(f"The Range of Cases_Pending_Investigation_from_Previous_Year is : {Cases_Pending_Investigation_from_Previous_Year}.")
print(f"The Range of Cases_Reported_during_the_year is : {Cases_Reported_during_the_year}.")
print(f"The Range of Cases_ReOpened_for_Investigation is : {Cases_ReOpened_for_Investigation}.")
print(f"The Range of Cases_Transferred_to_other_1_or_Agency is : {Cases_Transferred_to_other_1_or_Agency}.")
print(f"The Range of Cases_in_Which_Final_Reports_Submitted is : {Cases_in_Which_Final_Reports_Submitted}.")
print(f"The Range of Cases_With_drawn_by_the_Govt is : {Cases_With_drawn_by_the_Govt}.")
print(f"The Range of Cases_Charge_sheeted is : {Cases_Charge_sheeted}.")
print(f"The Range of Cases_Pending_Investigation_at_End_of_the_Year is : {Cases_Pending_Investigation_at_End_of_the_Year}.")
print(f"The Range of Total_cases is : {Total_cases}.")
# Out:
# The Range of Category is : 1.
# The Range of Cases_Pending_Investigation_from_Previous_Year is : 1609.
# The Range of Cases_Reported_during_the_year is : 891.
# The Range of Cases_ReOpened_for_Investigation is : 7.
# The Range of Cases_Transferred_to_other_1_or_Agency is : 6.
# The Range of Cases_in_Which_Final_Reports_Submitted is : 141.
# The Range of Cases_With_drawn_by_the_Govt is : 1.
# The Range of Cases_Charge_sheeted is : 808.
# The Range of Cases_Pending_Investigation_at_End_of_the_Year is : 1693.
# The Range of Total_cases is : 2033.

# %%
#interQuartile
interquartilerange= percent75 - percent25

print("*********************************************************************************************************")
print("interquartile range")
print("*********************************************************************************************************")
print(f"\n{interquartilerange}\n")
# Out:
# *********************************************************************************************************
# interquartile range
# *********************************************************************************************************
#
# Category                                            0.00
# State_UT                                           16.50
# Cases_Pending_Investigation_from_Previous_Year    329.00
# Cases_Reported_during_the_year                    137.75
# Cases_ReOpened_for_Investigation                    0.00
# Cases_Transferred_to_other_1_or_Agency              0.00
# Cases_With_drawn_by_the_Govt                        0.00
# Cases_in_Which_Final_Reports_Submitted             10.25
# Cases_Charge_sheeted                               77.25
# Cases_Pending_Investigation_at_End_of_the_Year    382.75
# Total_cases                                       468.75
# Unnamed: 11                                          NaN
# ...

# %%
# Coefficient Viriation 
data.std()/data.mean()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\471100910.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()/data.mean()
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\471100910.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()/data.mean()
# Category                                          0.336044
# State_UT                                          0.566233
# Cases_Pending_Investigation_from_Previous_Year    1.419794
# Cases_Reported_during_the_year                    1.580981
# ...

# %%
#reggresion slope

x = data['Cases_With_drawn_by_the_Govt']
y = data['Total_cases']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
regression_intercept = model.params['const']
print(regression_intercept)
# Out:
# 391.5999999999999

# %%
# Correlation
data.corr()
# Out:
# C:\Users\kubayim\AppData\Local\Temp\ipykernel_26568\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                                 Category  State_UT  \
# Category                                        1.000000  0.691312
# State_UT                                        0.691312  1.000000
# Cases_Pending_Investigation_from_Previous_Year -0.302744 -0.175105
# Cases_Reported_during_the_year                 -0.304471 -0.143814
# Cases_ReOpened_for_Investigation               -0.191911 -0.300151
# Cases_Transferred_to_other_1_or_Agency         -0.105810 -0.156741
# Cases_With_drawn_by_the_Govt                   -0.083045 -0.145806
# Cases_in_Which_Final_Reports_Submitted         -0.223362 -0.061383
# Cases_Charge_sheeted                           -0.250625 -0.152686
# ...

# %%
#Took 1st 5 from the head
data.head()
# Out:
#    Category  State_UT  Cases_Pending_Investigation_from_Previous_Year  \
# 0         1         1                                             360
# 1         1         2                                              63
# 2         1         3                                              96
# 3         1         4                                             288
# 4         1         5                                              69
#
#    Cases_Reported_during_the_year  Cases_ReOpened_for_Investigation  \
# 0                             123                                 0
# 1                              13                                 0
# 2                              18                                 0
# 3                              71                                 2
# 4                              19                                 0
#
#    Cases_Transferred_to_other_1_or_Agency  Cases_With_drawn_by_the_Govt  \
# ...

# %%
sns.countplot(x="Cases_Charge_sheeted", data=data,palette="bwr")
plt.title("Cases_Charge_sheeted")
plt.show()

# %% [markdown]
# # Comment for bar Graph
#
# * These are all the cases that has been charged, when you look at count which is under 0/Zero it has a high level of cases that was not charged meaing that in 2019 75% of the cases were not charged and about 25 % were charged when you look at the red part.
# * Charged/Blue
# * Not Charged/Red

# %%
Total_cases=data["Total_cases"]
plt.figure(figsize=(10,5))
plt.hist(Total_cases,bins=40)
plt.title("Total_cases",fontsize=16)
plt.xlabel("Total_cases",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# # Comment Total Cases
# * The  Total cases were low in year 2019 due to there are recuring cases from the previous year.
# when you llok at count 2 and the total cases which is 2000 it shows that in this year up to 2000 3000 cases were reported mixed with the rest of the cases for example final report, reorted during the year and end of year.

# %%
pd.crosstab(data.Cases_Reported_during_the_year,data.Cases_in_Which_Final_Reports_Submitted).plot(kind="bar",figsize=(20,6))
plt.title('Reported and final report')
plt.xlabel('Cases')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Coment Cases With Drawn by the govt
#
# * This Graph shows that how many times does cases get reported and how amny final reprts where submited, looking at the frequency under 0,1,6 are at a hig frquency and has less cases in 2019

# %%
# Corruption Pie Chart
labels = ['Cases_Pending_Investigation_at_End_of_the_Year', 'Cases_in_Which_Final_Reports_Submitted', 'Cases_Pending_Investigation_from_Previous_Year']
sizes = [30, 40, 20]

# Create a pie chart
plt.pie(sizes, labels=labels)

# Add a title
plt.title('Corruption1')

# Display the chart
plt.show()

# %% [markdown]
# # Comment Corruption1
#
# * Cases_Pending_Investigation_from_Previous_Year has 25% and Cases in which Fina reports submitted has 65% and cases pening is 10 %, it shows that Cases submited (Orange) has the most frequency coun and max.

# %%
# sample data
x = ['Pending', 'Transferred', 'Final_Reports', 'End_Year', 'Submitted']
y = [10, 8, 5, 6, 12]

# create a dot plot
fig, ax = plt.subplots()
ax.scatter(x, y)

# add labels and title
ax.set_xlabel('Number')
ax.set_ylabel('Frequency')
ax.set_title('Corruption Cases')

# display the plot
plt.show()

# %% [markdown]
# # (Cases)Pending/Transferred/Final/End_year/Submitted Reports
# * Pending casas are the higest more than the rest of the cases
# * llok at the frequency of 10 and passes the penical

# %% [markdown]
# ## Comments
#
#                                        *Diffrence Between Pythond and Excel Stats
#
# The Calculation of the python is much more easier to do, some of the discriptive data that i have done on Python i was unable to perform on Excel due to the excel formulars were abit confusing.
# when you run a python formular and click enter shit it gives me the whole answer with more detail to how the calculation was performed.
# The graphs on Excel are more descriptive and easy to understand.
# Python is abit har cause for my self i hard to start getting familiar to the programming laungue for the first time in my life.
#
#                                                 *Conclusion of My data
#
# My data shows the inter relation of the cases that were open in the year 2019 and what happened to the cases most of the cases the average cases and and case screnarion to be looked at is the number of cases still pending by the end of the year it has a high outline and most of the states have a hig average of cases that are put on pending and still under investigation.
# Its interseting due to most of the cases that are alos contribuing in average are cases from the previos year with a whooping of 275 average making it a high number at the end of the year.
#
# No Cases has been closed just have cases that are still ongoing with a hi frequency of the case pending.
